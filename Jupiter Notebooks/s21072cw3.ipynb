# %% [markdown]
# Ćwiczenia 3

# %%
import os
import pandas as pd
from google.colab import drive
from platform import python_version

drive.mount('/content/drive')
os.chdir('/content/drive/My Drive/')
base_data = pd.read_csv("DSP_4.csv")
# Out:
# Mounted at /content/drive

# %% [markdown]
# Zadanie 1

# %%
df = ['ala', 'ma','kota']

# %%
display(df)
# Out:
# ['ala', 'ma', 'kota']

# %% [markdown]
# Zadanie 2

# %%
df = pd.read_csv("DSP_4.csv", sep = ';')

# %%
df.isnull().any()
# Out:
# objawy     False
# wiek        True
# choroby    False
# wzrost      True
# leki       False
# dtype: bool

# %%
df.columns
# Out:
# Index(['objawy', 'wiek', 'choroby', 'wzrost', 'leki'], dtype='object')

# %%
df_3 = df.fillna(df.median())
display(df_3)
print(df['wiek'].median()) 
print(df["wzrost"].median())
# Out:
#     objawy  wiek  choroby  wzrost  leki
# 0        1  43.0        0   170.0     2
# 1        1  65.0        0   187.0     3
# 2        1  55.0        0   182.0     4
# 3        1  44.0        0   187.0     3
# 4        1  77.0        0   165.0     2
# 5        1  64.0        0   164.0     1
# 6        1  54.0        1   178.0     4
# 7        1  43.0        1   190.0     3
# 8        3  76.0        1   200.0     2
# 9        3  54.0        0   198.0     1
# 10       3  56.0        0   187.0     2
# 11       3  68.0        0   167.0     3
# 12       3  43.0        1   168.0     2
# 13       3  55.0        1   189.0     1
# 14       3  44.0        1   177.0     2
# 15       3  43.0        1   166.0     3
# 16       2  32.0        1   188.0     4
# 17       2  23.0        1   198.0     3
# 18       2  42.0        0   176.0     2
# 19       2  43.0        0   167.0     1
# 20       2  11.0        0   159.0     2
# 21       2  21.0        0   198.0     3
# 22       2  34.0        1   192.0     4
# 23       2  32.0        1   187.0     1
# 24       2  12.0        2   194.0     4
# 25       2  43.0        0   199.0     1
# 26       2  33.0        1   200.0     2
# 27       2  42.0        2   187.0     3
# 28       2  32.0        0   168.0     4
# 29       2  34.0        1   187.0     3
# 30       1  67.0        5   170.0     2
# 31       1  65.0        4   188.0     3
# 32       1  55.0        5   182.0     4
# 33       1  44.0        4   187.0     3
# 34       1  77.0        5   165.0     2
# 35       1  64.0        3   187.0     1
# 36       4  54.0        4   178.0     4
# 37       4  34.0        5   190.0     3
# 38       4  76.0        5   200.0     2
# 39       4  54.0        4   198.0     1
# 40       4  56.0        3   187.0     2
# 41       4  68.0        2   167.0     3
# 42       4  76.0        3   168.0     2
# 43       4  55.0        4   189.0     1
# 44       4  44.0        2   187.0     2
# 45       4  43.0        0   166.0     3
# 46       2  32.0        1   188.0     4
# 47       2  23.0        1   198.0     3
# 48       2  42.0        0   176.0     2
# 49       2  21.0        0   167.0     1
# 50       2  11.0        0   187.0     2
# 51       2  21.0        0   198.0     3
# 52       2  34.0        1   192.0     4
# 53       2  32.0        1   194.0     1
# 54       5  12.0        2   194.0     4
# 55       5  25.0        0   199.0     1
# 56       5  33.0        1   200.0     2
# 57       5  42.0        2   187.0     3
# 58       5  32.0        0   168.0     4
# 59       5  34.0        1   187.0     3
# 43.0
# 187.0

# %%
df_4 = df.fillna(0)
display(df_4)
# Out:
#     objawy  wiek  choroby  wzrost  leki
# 0        1   0.0        0   170.0     2
# 1        1  65.0        0     0.0     3
# 2        1  55.0        0   182.0     4
# 3        1  44.0        0   187.0     3
# 4        1  77.0        0   165.0     2
# 5        1  64.0        0   164.0     1
# 6        1  54.0        1   178.0     4
# 7        1   0.0        1   190.0     3
# 8        3  76.0        1   200.0     2
# 9        3  54.0        0   198.0     1
# 10       3  56.0        0   187.0     2
# 11       3  68.0        0   167.0     3
# 12       3   0.0        1   168.0     2
# 13       3  55.0        1   189.0     1
# 14       3  44.0        1   177.0     2
# 15       3  43.0        1   166.0     3
# 16       2  32.0        1   188.0     4
# 17       2  23.0        1   198.0     3
# 18       2  42.0        0   176.0     2
# 19       2   0.0        0   167.0     1
# 20       2  11.0        0   159.0     2
# 21       2  21.0        0   198.0     3
# 22       2  34.0        1   192.0     4
# 23       2  32.0        1     0.0     1
# 24       2  12.0        2   194.0     4
# 25       2   0.0        0   199.0     1
# 26       2  33.0        1   200.0     2
# 27       2  42.0        2   187.0     3
# 28       2  32.0        0   168.0     4
# 29       2  34.0        1   187.0     3
# 30       1  67.0        5   170.0     2
# 31       1  65.0        4   188.0     3
# 32       1  55.0        5   182.0     4
# 33       1  44.0        4   187.0     3
# 34       1  77.0        5   165.0     2
# 35       1  64.0        3     0.0     1
# 36       4  54.0        4   178.0     4
# 37       4  34.0        5   190.0     3
# 38       4  76.0        5   200.0     2
# 39       4  54.0        4   198.0     1
# 40       4  56.0        3   187.0     2
# 41       4  68.0        2   167.0     3
# 42       4  76.0        3   168.0     2
# 43       4  55.0        4   189.0     1
# 44       4  44.0        2     0.0     2
# 45       4  43.0        0   166.0     3
# 46       2  32.0        1   188.0     4
# 47       2  23.0        1   198.0     3
# 48       2  42.0        0   176.0     2
# 49       2  21.0        0   167.0     1
# 50       2  11.0        0     0.0     2
# 51       2  21.0        0   198.0     3
# 52       2  34.0        1   192.0     4
# 53       2  32.0        1   194.0     1
# 54       5  12.0        2   194.0     4
# 55       5  25.0        0   199.0     1
# 56       5  33.0        1   200.0     2
# 57       5  42.0        2   187.0     3
# 58       5  32.0        0   168.0     4
# 59       5  34.0        1   187.0     3

# %% [markdown]
# Zadanie 3

# %%
df_5 = pd.read_csv("DSP_5.csv", sep = ';')

# %%
df_5.isnull().any()
# Out:
# model    False
# mpg      False
# cyl      False
# disp     False
# hp        True
# drat     False
# wt        True
# qsec     False
# vs       False
# am       False
# gear     False
# carb     False
# dtype: bool

# %%
df_5 = df_5.fillna(df_5.mean())
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.

# %%
print(df_5['hp'].mean()) 
print(df_5['hp'].var()) 
print(df_5['hp'].max() - df_5['hp'].min())
# Out:
# 143.51612903225805
# 4379.023933402706
# 283.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import pearsonr

# %%
df_5.corr()
# Out:
#            mpg       cyl      disp        hp      drat        wt      qsec  \
# mpg   1.000000 -0.852162 -0.847551 -0.748447  0.681172 -0.864418  0.418684
# cyl  -0.852162  1.000000  0.902033  0.812289 -0.699938  0.776755 -0.591242
# disp -0.847551  0.902033  1.000000  0.771889 -0.710214  0.885379 -0.433698
# hp   -0.748447  0.812289  0.771889  1.000000 -0.477304  0.650904 -0.666273
# drat  0.681172 -0.699938 -0.710214 -0.477304  1.000000 -0.711907  0.091205
# wt   -0.864418  0.776755  0.885379  0.650904 -0.711907  1.000000 -0.176005
# qsec  0.418684 -0.591242 -0.433698 -0.666273  0.091205 -0.176005  1.000000
# vs    0.664039 -0.810812 -0.710416 -0.706256  0.440278 -0.557854  0.744535
# am    0.599832 -0.522607 -0.591227 -0.211707  0.712711 -0.680956 -0.229861
# gear  0.480285 -0.492687 -0.555569 -0.084144  0.699610 -0.580341 -0.212682
# carb -0.550925  0.526988  0.394977  0.740507 -0.090790  0.426549 -0.656249
#
#             vs        am      gear      carb
# mpg   0.664039  0.599832  0.480285 -0.550925
# cyl  -0.810812 -0.522607 -0.492687  0.526988
# disp -0.710416 -0.591227 -0.555569  0.394977
# hp   -0.706256 -0.211707 -0.084144  0.740507
# drat  0.440278  0.712711  0.699610 -0.090790
# wt   -0.557854 -0.680956 -0.580341  0.426549
# qsec  0.744535 -0.229861 -0.212682 -0.656249
# vs    1.000000  0.168345  0.206023 -0.569607
# am    0.168345  1.000000  0.794059  0.057534
# gear  0.206023  0.794059  1.000000  0.274073
# carb -0.569607  0.057534  0.274073  1.000000

# %%
plt.figure(figsize=(10, 5)) 
# określamy wielkość tabeli, którą generujemy
heatmap = sns.heatmap(df_5.corr(), vmin=-1, vmax=1, annot=True) 
# odwołujemy się do metody tj. mapy ciepła
heatmap.set_title('Analiza korelacji', fontdict={'fontsize':14}, pad=12)
# Out:
# Text(0.5, 1.0, 'Analiza korelacji')

# %%
r = df.corr()
# na początek zapisujemy nową zmienną, która jest tabelą korelacji
p = df.corr(method=lambda x, y: pearsonr(x, y)[1]) - np.eye(*r.shape)
# następnie, nie wchodząc w szczegóły, definiujemy wartość p
p = p.applymap(lambda x: ''.join(['*' for t in [0.01,0.05,0.1] if x<=t]))
r.round(2).astype(str) + p
# nakładamy wartość p na tabelę korelacji
# Out:
#          objawy     wiek  choroby   wzrost    leki
# objawy   1.0***    -0.11     0.11     0.17   -0.05
# wiek      -0.11   1.0***  0.39***  -0.29**  -0.23*
# choroby    0.11  0.39***   1.0***     0.11    0.05
# wzrost     0.17  -0.29**     0.11   1.0***    0.01
# leki      -0.05   -0.23*     0.05     0.01  1.0***

# %% [markdown]
# Zadanie 4

# %%
df_8 = pd.read_csv("DSP_8.csv", sep = ',')

# %%
display(df_8)
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0      172              N      0.0       Up             0
# 1      156              N      1.0     Flat             1
# 2       98              N      0.0       Up             0
# 3      108              Y      1.5     Flat             1
# 4      122              N      0.0       Up             0
# ..     ...            ...      ...      ...           ...
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0
#
# [918 rows x 12 columns]

# %%
#column number
len(df_5.columns)
# Out:
# 12

# %%
#rows number
len(df_8.index)
# Out:
# 918

# %%
#missing data
df_8.isnull().any()
# Out:
# Age               False
# Sex               False
# ChestPainType     False
# RestingBP         False
# Cholesterol       False
# FastingBS         False
# RestingECG        False
# MaxHR             False
# ExerciseAngina    False
# Oldpeak           False
# ST_Slope          False
# HeartDisease      False
# dtype: bool

# %%
#The mean age and standard deviation in two separate gorups (men&women)
print(round(df_8['Age'].groupby(df_8['Sex']).mean(),2))
print(round(df_8['Age'].groupby(df_8['Sex']).std(),2))
# Out:
# Sex
# F    52.49
# M    53.78
# Name: Age, dtype: float64
# Sex
# F    9.52
# M    9.40
# Name: Age, dtype: float64

# %%
#the percentage of men in the dataset
counter = 0
for pp in df_8['Sex']:
  if (pp == 'M'):
    counter+=1
print(round(counter/len(df_8.index)*100,2), '%')
# Out:
# 78.98 %

# %%
#the number of women aged 45 to 50 years
counter = 0
for pp in df_8[df_8['Sex']=='F']['Age']:
  if (45 < pp < 50):
    counter+=1
print(counter)
# Out:
# 23

# %%
#correlation between the variables, but only for people with their ECG at rest is normal (when in the RestingECG column, "Normal" appears)
#df_8.corr()
df_8[df_8['RestingECG']=='Normal'].corr()
# Out:
#                    Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  \
# Age           1.000000   0.230469    -0.129005   0.183535 -0.380244  0.246627
# RestingBP     0.230469   1.000000     0.142830  -0.010983 -0.124514  0.120313
# Cholesterol  -0.129005   0.142830     1.000000  -0.351044  0.224505  0.028653
# FastingBS     0.183535  -0.010983    -0.351044   1.000000 -0.111782  0.078385
# MaxHR        -0.380244  -0.124514     0.224505  -0.111782  1.000000 -0.195590
# Oldpeak       0.246627   0.120313     0.028653   0.078385 -0.195590  1.000000
# HeartDisease  0.241428   0.051725    -0.276377   0.277575 -0.427006  0.433986
#
#               HeartDisease
# Age               0.241428
# RestingBP         0.051725
# Cholesterol      -0.276377
# FastingBS         0.277575
# MaxHR            -0.427006
# Oldpeak           0.433986
# HeartDisease      1.000000
