# %% [markdown]
# # Data Science z Python 3.10. Konwersja modeli (fast.ai & TensorFlow)
# ## 🇬🇧 Data Science with Python 3.10. Model conversion (fast.ai & TensorFlow)
# #### 👨‍🏫 PhD Wojciech Oronowicz-Jaśkowiak
# #### 🤖 https://github.com/aipogodzinach

# %% [markdown]
# ## Zadanie 1.
# ### Task 1.

# %%
# pip install numpy keras tensorflow tf2onnx

import os
import numpy as np
import shutil
import keras

from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.applications import ResNet50

# %%
base_dir = 'dataset_x5'
data_dir = 'data_dir'

raw_no_of_files = {}
classes = ['class1', 'class2', 'class3']
for dir in classes:
    raw_no_of_files[dir] = len(os.listdir(os.path.join(base_dir, dir)))
raw_no_of_files.items()
# Out:
# dict_items([('class1', 111), ('class2', 114), ('class3', 136)])

# %%
if not os.path.exists(data_dir):
    os.mkdir(data_dir)

train_dir = os.path.join(data_dir, 'train')
valid_dir = os.path.join(data_dir, 'valid')
test_dir = os.path.join(data_dir, 'test')

train_class1_dir = os.path.join(train_dir, '1')
train_class2_dir = os.path.join(train_dir, '2')
train_class3_dir = os.path.join(train_dir, '3')

valid_class1_dir = os.path.join(valid_dir, '1')
valid_class2_dir = os.path.join(valid_dir, '2')
valid_class3_dir = os.path.join(valid_dir, '3')

test_class1_dir = os.path.join(test_dir, '1')
test_class2_dir = os.path.join(test_dir, '2')
test_class3_dir = os.path.join(test_dir, '3')

for directory in (train_dir, valid_dir, test_dir):
    if not os.path.exists(directory):
        os.mkdir(directory)

dirs = [train_class1_dir, train_class2_dir, train_class3_dir,
        valid_class1_dir, valid_class2_dir, valid_class3_dir,
        test_class1_dir, test_class2_dir, test_class3_dir]

for dir in dirs:
    if not os.path.exists(dir):
        os.mkdir(dir)

# %%
class1_fnames = os.listdir(os.path.join(base_dir, 'class1'))
class2_fnames = os.listdir(os.path.join(base_dir, 'class2'))
class3_fnames = os.listdir(os.path.join(base_dir, 'class3'))

class1_fnames = [fname for fname in class1_fnames if fname.split('.')[1].lower() in ['jpg', 'png', 'jpeg']]
class2_fnames = [fname for fname in class2_fnames if fname.split('.')[1].lower() in ['jpg', 'png', 'jpeg']]
class3_fnames = [fname for fname in class3_fnames if fname.split('.')[1].lower() in ['jpg', 'png', 'jpeg']]

# %%
size = min(len(class1_fnames), len(class2_fnames), len(class3_fnames))

train_size = int(np.floor(0.7 * size))
valid_size = int(np.floor(0.2 * size))
test_size = size - train_size - valid_size

train_idx = train_size
valid_idx = train_size + valid_size
test_idx = train_size + valid_size + test_size

# %%
for i, fname in enumerate(class1_fnames):
    if i <= train_idx:
        src = os.path.join(base_dir, 'class1', fname)
        dst = os.path.join(train_class1_dir, fname)
        shutil.copyfile(src, dst)
    elif train_idx < i <= valid_idx:
        src = os.path.join(base_dir, 'class1', fname)
        dst = os.path.join(valid_class1_dir, fname)
        shutil.copyfile(src, dst)
    elif valid_idx < i < test_idx:
        src = os.path.join(base_dir, 'class1', fname)
        dst = os.path.join(test_class1_dir, fname)
        shutil.copyfile(src, dst)

for i, fname in enumerate(class2_fnames):
    if i <= train_idx:
        src = os.path.join(base_dir, 'class2', fname)
        dst = os.path.join(train_class2_dir, fname)
        shutil.copyfile(src, dst)
    elif train_idx < i <= valid_idx:
        src = os.path.join(base_dir, 'class2', fname)
        dst = os.path.join(valid_class2_dir, fname)
        shutil.copyfile(src, dst)
    elif valid_idx < i < test_idx:
        src = os.path.join(base_dir, 'class2', fname)
        dst = os.path.join(test_class2_dir, fname)
        shutil.copyfile(src, dst) 

for i, fname in enumerate(class3_fnames):
    if i <= train_idx:
        src = os.path.join(base_dir, 'class3', fname)
        dst = os.path.join(train_class3_dir, fname)
        shutil.copyfile(src, dst)
    elif train_idx < i <= valid_idx:
        src = os.path.join(base_dir, 'class3', fname)
        dst = os.path.join(valid_class3_dir, fname)
        shutil.copyfile(src, dst)
    elif valid_idx < i < test_idx:
        src = os.path.join(base_dir, 'class3', fname)
        dst = os.path.join(test_class3_dir, fname)
        shutil.copyfile(src, dst)

# %%
train_datagen = ImageDataGenerator()

valid_datagen = ImageDataGenerator(rescale=1./255.)

train_generator = train_datagen.flow_from_directory(directory=train_dir,
                                                   target_size=(150, 150),
                                                   batch_size=32,
                                                   class_mode='categorical')

valid_generator = valid_datagen.flow_from_directory(directory=valid_dir,
                                                   target_size=(150, 150),
                                                   batch_size=32,
                                                   class_mode='categorical')
# Out:
# Found 234 images belonging to 3 classes.
# Found 66 images belonging to 3 classes.

# %%
batch_size = 20
steps_per_epoch = train_size // batch_size
validation_steps = valid_size // batch_size

# %%
conv_base = ResNet50(weights='imagenet', include_top=False, input_shape=(150, 150, 3))
conv_base.trainable = True

def print_layers(model):
    for layer in model.layers:
        print(f'layer_name: {layer.name:13} trainable: {layer.trainable}')

print_layers(conv_base)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 8s 0us/step
# layer_name: input_1       trainable: True
# layer_name: conv1_pad     trainable: True
# layer_name: conv1_conv    trainable: True
# layer_name: conv1_bn      trainable: True
# layer_name: conv1_relu    trainable: True
# layer_name: pool1_pad     trainable: True
# layer_name: pool1_pool    trainable: True
# layer_name: conv2_block1_1_conv trainable: True
# layer_name: conv2_block1_1_bn trainable: True
# layer_name: conv2_block1_1_relu trainable: True
# layer_name: conv2_block1_2_conv trainable: True
# layer_name: conv2_block1_2_bn trainable: True
# layer_name: conv2_block1_2_relu trainable: True
# layer_name: conv2_block1_0_conv trainable: True
# layer_name: conv2_block1_3_conv trainable: True
# layer_name: conv2_block1_0_bn trainable: True
# layer_name: conv2_block1_3_bn trainable: True
# layer_name: conv2_block1_add trainable: True
# layer_name: conv2_block1_out trainable: True
# layer_name: conv2_block2_1_conv trainable: True
# layer_name: conv2_block2_1_bn trainable: True
# layer_name: conv2_block2_1_relu trainable: True
# layer_name: conv2_block2_2_conv trainable: True
# layer_name: conv2_block2_2_bn trainable: True
# layer_name: conv2_block2_2_relu trainable: True
# layer_name: conv2_block2_3_conv trainable: True
# layer_name: conv2_block2_3_bn trainable: True
# layer_name: conv2_block2_add trainable: True
# layer_name: conv2_block2_out trainable: True
# layer_name: conv2_block3_1_conv trainable: True
# layer_name: conv2_block3_1_bn trainable: True
# layer_name: conv2_block3_1_relu trainable: True
# layer_name: conv2_block3_2_conv trainable: True
# layer_name: conv2_block3_2_bn trainable: True
# layer_name: conv2_block3_2_relu trainable: True
# layer_name: conv2_block3_3_conv trainable: True
# layer_name: conv2_block3_3_bn trainable: True
# layer_name: conv2_block3_add trainable: True
# layer_name: conv2_block3_out trainable: True
# layer_name: conv3_block1_1_conv trainable: True
# layer_name: conv3_block1_1_bn trainable: True
# layer_name: conv3_block1_1_relu trainable: True
# layer_name: conv3_block1_2_conv trainable: True
# layer_name: conv3_block1_2_bn trainable: True
# layer_name: conv3_block1_2_relu trainable: True
# layer_name: conv3_block1_0_conv trainable: True
# layer_name: conv3_block1_3_conv trainable: True
# layer_name: conv3_block1_0_bn trainable: True
# layer_name: conv3_block1_3_bn trainable: True
# layer_name: conv3_block1_add trainable: True
# layer_name: conv3_block1_out trainable: True
# layer_name: conv3_block2_1_conv trainable: True
# layer_name: conv3_block2_1_bn trainable: True
# layer_name: conv3_block2_1_relu trainable: True
# layer_name: conv3_block2_2_conv trainable: True
# layer_name: conv3_block2_2_bn trainable: True
# layer_name: conv3_block2_2_relu trainable: True
# layer_name: conv3_block2_3_conv trainable: True
# layer_name: conv3_block2_3_bn trainable: True
# layer_name: conv3_block2_add trainable: True
# layer_name: conv3_block2_out trainable: True
# layer_name: conv3_block3_1_conv trainable: True
# layer_name: conv3_block3_1_bn trainable: True
# layer_name: conv3_block3_1_relu trainable: True
# layer_name: conv3_block3_2_conv trainable: True
# layer_name: conv3_block3_2_bn trainable: True
# layer_name: conv3_block3_2_relu trainable: True
# layer_name: conv3_block3_3_conv trainable: True
# layer_name: conv3_block3_3_bn trainable: True
# layer_name: conv3_block3_add trainable: True
# layer_name: conv3_block3_out trainable: True
# layer_name: conv3_block4_1_conv trainable: True
# layer_name: conv3_block4_1_bn trainable: True
# layer_name: conv3_block4_1_relu trainable: True
# layer_name: conv3_block4_2_conv trainable: True
# layer_name: conv3_block4_2_bn trainable: True
# layer_name: conv3_block4_2_relu trainable: True
# layer_name: conv3_block4_3_conv trainable: True
# layer_name: conv3_block4_3_bn trainable: True
# layer_name: conv3_block4_add trainable: True
# layer_name: conv3_block4_out trainable: True
# layer_name: conv4_block1_1_conv trainable: True
# layer_name: conv4_block1_1_bn trainable: True
# layer_name: conv4_block1_1_relu trainable: True
# layer_name: conv4_block1_2_conv trainable: True
# layer_name: conv4_block1_2_bn trainable: True
# layer_name: conv4_block1_2_relu trainable: True
# layer_name: conv4_block1_0_conv trainable: True
# layer_name: conv4_block1_3_conv trainable: True
# layer_name: conv4_block1_0_bn trainable: True
# layer_name: conv4_block1_3_bn trainable: True
# layer_name: conv4_block1_add trainable: True
# layer_name: conv4_block1_out trainable: True
# layer_name: conv4_block2_1_conv trainable: True
# layer_name: conv4_block2_1_bn trainable: True
# layer_name: conv4_block2_1_relu trainable: True
# layer_name: conv4_block2_2_conv trainable: True
# layer_name: conv4_block2_2_bn trainable: True
# layer_name: conv4_block2_2_relu trainable: True
# layer_name: conv4_block2_3_conv trainable: True
# layer_name: conv4_block2_3_bn trainable: True
# layer_name: conv4_block2_add trainable: True
# layer_name: conv4_block2_out trainable: True
# layer_name: conv4_block3_1_conv trainable: True
# layer_name: conv4_block3_1_bn trainable: True
# layer_name: conv4_block3_1_relu trainable: True
# layer_name: conv4_block3_2_conv trainable: True
# layer_name: conv4_block3_2_bn trainable: True
# layer_name: conv4_block3_2_relu trainable: True
# layer_name: conv4_block3_3_conv trainable: True
# layer_name: conv4_block3_3_bn trainable: True
# layer_name: conv4_block3_add trainable: True
# layer_name: conv4_block3_out trainable: True
# layer_name: conv4_block4_1_conv trainable: True
# layer_name: conv4_block4_1_bn trainable: True
# layer_name: conv4_block4_1_relu trainable: True
# layer_name: conv4_block4_2_conv trainable: True
# layer_name: conv4_block4_2_bn trainable: True
# layer_name: conv4_block4_2_relu trainable: True
# layer_name: conv4_block4_3_conv trainable: True
# layer_name: conv4_block4_3_bn trainable: True
# layer_name: conv4_block4_add trainable: True
# layer_name: conv4_block4_out trainable: True
# layer_name: conv4_block5_1_conv trainable: True
# layer_name: conv4_block5_1_bn trainable: True
# layer_name: conv4_block5_1_relu trainable: True
# layer_name: conv4_block5_2_conv trainable: True
# layer_name: conv4_block5_2_bn trainable: True
# layer_name: conv4_block5_2_relu trainable: True
# layer_name: conv4_block5_3_conv trainable: True
# layer_name: conv4_block5_3_bn trainable: True
# layer_name: conv4_block5_add trainable: True
# layer_name: conv4_block5_out trainable: True
# layer_name: conv4_block6_1_conv trainable: True
# layer_name: conv4_block6_1_bn trainable: True
# layer_name: conv4_block6_1_relu trainable: True
# layer_name: conv4_block6_2_conv trainable: True
# layer_name: conv4_block6_2_bn trainable: True
# layer_name: conv4_block6_2_relu trainable: True
# layer_name: conv4_block6_3_conv trainable: True
# layer_name: conv4_block6_3_bn trainable: True
# layer_name: conv4_block6_add trainable: True
# layer_name: conv4_block6_out trainable: True
# layer_name: conv5_block1_1_conv trainable: True
# layer_name: conv5_block1_1_bn trainable: True
# layer_name: conv5_block1_1_relu trainable: True
# layer_name: conv5_block1_2_conv trainable: True
# layer_name: conv5_block1_2_bn trainable: True
# layer_name: conv5_block1_2_relu trainable: True
# layer_name: conv5_block1_0_conv trainable: True
# layer_name: conv5_block1_3_conv trainable: True
# layer_name: conv5_block1_0_bn trainable: True
# layer_name: conv5_block1_3_bn trainable: True
# layer_name: conv5_block1_add trainable: True
# layer_name: conv5_block1_out trainable: True
# layer_name: conv5_block2_1_conv trainable: True
# layer_name: conv5_block2_1_bn trainable: True
# layer_name: conv5_block2_1_relu trainable: True
# layer_name: conv5_block2_2_conv trainable: True
# layer_name: conv5_block2_2_bn trainable: True
# layer_name: conv5_block2_2_relu trainable: True
# layer_name: conv5_block2_3_conv trainable: True
# layer_name: conv5_block2_3_bn trainable: True
# layer_name: conv5_block2_add trainable: True
# layer_name: conv5_block2_out trainable: True
# layer_name: conv5_block3_1_conv trainable: True
# layer_name: conv5_block3_1_bn trainable: True
# layer_name: conv5_block3_1_relu trainable: True
# layer_name: conv5_block3_2_conv trainable: True
# layer_name: conv5_block3_2_bn trainable: True
# layer_name: conv5_block3_2_relu trainable: True
# layer_name: conv5_block3_3_conv trainable: True
# layer_name: conv5_block3_3_bn trainable: True
# layer_name: conv5_block3_add trainable: True
# layer_name: conv5_block3_out trainable: True

# %%
set_trainable = False
for layer in conv_base.layers:
    if layer.name == 'block5_conv1':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False

print_layers(conv_base)
# Out:
# layer_name: input_1       trainable: False
# layer_name: conv1_pad     trainable: False
# layer_name: conv1_conv    trainable: False
# layer_name: conv1_bn      trainable: False
# layer_name: conv1_relu    trainable: False
# layer_name: pool1_pad     trainable: False
# layer_name: pool1_pool    trainable: False
# layer_name: conv2_block1_1_conv trainable: False
# layer_name: conv2_block1_1_bn trainable: False
# layer_name: conv2_block1_1_relu trainable: False
# layer_name: conv2_block1_2_conv trainable: False
# layer_name: conv2_block1_2_bn trainable: False
# layer_name: conv2_block1_2_relu trainable: False
# layer_name: conv2_block1_0_conv trainable: False
# layer_name: conv2_block1_3_conv trainable: False
# layer_name: conv2_block1_0_bn trainable: False
# layer_name: conv2_block1_3_bn trainable: False
# layer_name: conv2_block1_add trainable: False
# layer_name: conv2_block1_out trainable: False
# layer_name: conv2_block2_1_conv trainable: False
# layer_name: conv2_block2_1_bn trainable: False
# layer_name: conv2_block2_1_relu trainable: False
# layer_name: conv2_block2_2_conv trainable: False
# layer_name: conv2_block2_2_bn trainable: False
# layer_name: conv2_block2_2_relu trainable: False
# layer_name: conv2_block2_3_conv trainable: False
# layer_name: conv2_block2_3_bn trainable: False
# layer_name: conv2_block2_add trainable: False
# layer_name: conv2_block2_out trainable: False
# layer_name: conv2_block3_1_conv trainable: False
# layer_name: conv2_block3_1_bn trainable: False
# layer_name: conv2_block3_1_relu trainable: False
# layer_name: conv2_block3_2_conv trainable: False
# layer_name: conv2_block3_2_bn trainable: False
# layer_name: conv2_block3_2_relu trainable: False
# layer_name: conv2_block3_3_conv trainable: False
# layer_name: conv2_block3_3_bn trainable: False
# layer_name: conv2_block3_add trainable: False
# layer_name: conv2_block3_out trainable: False
# layer_name: conv3_block1_1_conv trainable: False
# layer_name: conv3_block1_1_bn trainable: False
# layer_name: conv3_block1_1_relu trainable: False
# layer_name: conv3_block1_2_conv trainable: False
# layer_name: conv3_block1_2_bn trainable: False
# layer_name: conv3_block1_2_relu trainable: False
# layer_name: conv3_block1_0_conv trainable: False
# layer_name: conv3_block1_3_conv trainable: False
# layer_name: conv3_block1_0_bn trainable: False
# layer_name: conv3_block1_3_bn trainable: False
# layer_name: conv3_block1_add trainable: False
# layer_name: conv3_block1_out trainable: False
# layer_name: conv3_block2_1_conv trainable: False
# layer_name: conv3_block2_1_bn trainable: False
# layer_name: conv3_block2_1_relu trainable: False
# layer_name: conv3_block2_2_conv trainable: False
# layer_name: conv3_block2_2_bn trainable: False
# layer_name: conv3_block2_2_relu trainable: False
# layer_name: conv3_block2_3_conv trainable: False
# layer_name: conv3_block2_3_bn trainable: False
# layer_name: conv3_block2_add trainable: False
# layer_name: conv3_block2_out trainable: False
# layer_name: conv3_block3_1_conv trainable: False
# layer_name: conv3_block3_1_bn trainable: False
# layer_name: conv3_block3_1_relu trainable: False
# layer_name: conv3_block3_2_conv trainable: False
# layer_name: conv3_block3_2_bn trainable: False
# layer_name: conv3_block3_2_relu trainable: False
# layer_name: conv3_block3_3_conv trainable: False
# layer_name: conv3_block3_3_bn trainable: False
# layer_name: conv3_block3_add trainable: False
# layer_name: conv3_block3_out trainable: False
# layer_name: conv3_block4_1_conv trainable: False
# layer_name: conv3_block4_1_bn trainable: False
# layer_name: conv3_block4_1_relu trainable: False
# layer_name: conv3_block4_2_conv trainable: False
# layer_name: conv3_block4_2_bn trainable: False
# layer_name: conv3_block4_2_relu trainable: False
# layer_name: conv3_block4_3_conv trainable: False
# layer_name: conv3_block4_3_bn trainable: False
# layer_name: conv3_block4_add trainable: False
# layer_name: conv3_block4_out trainable: False
# layer_name: conv4_block1_1_conv trainable: False
# layer_name: conv4_block1_1_bn trainable: False
# layer_name: conv4_block1_1_relu trainable: False
# layer_name: conv4_block1_2_conv trainable: False
# layer_name: conv4_block1_2_bn trainable: False
# layer_name: conv4_block1_2_relu trainable: False
# layer_name: conv4_block1_0_conv trainable: False
# layer_name: conv4_block1_3_conv trainable: False
# layer_name: conv4_block1_0_bn trainable: False
# layer_name: conv4_block1_3_bn trainable: False
# layer_name: conv4_block1_add trainable: False
# layer_name: conv4_block1_out trainable: False
# layer_name: conv4_block2_1_conv trainable: False
# layer_name: conv4_block2_1_bn trainable: False
# layer_name: conv4_block2_1_relu trainable: False
# layer_name: conv4_block2_2_conv trainable: False
# layer_name: conv4_block2_2_bn trainable: False
# layer_name: conv4_block2_2_relu trainable: False
# layer_name: conv4_block2_3_conv trainable: False
# layer_name: conv4_block2_3_bn trainable: False
# layer_name: conv4_block2_add trainable: False
# layer_name: conv4_block2_out trainable: False
# layer_name: conv4_block3_1_conv trainable: False
# layer_name: conv4_block3_1_bn trainable: False
# layer_name: conv4_block3_1_relu trainable: False
# layer_name: conv4_block3_2_conv trainable: False
# layer_name: conv4_block3_2_bn trainable: False
# layer_name: conv4_block3_2_relu trainable: False
# layer_name: conv4_block3_3_conv trainable: False
# layer_name: conv4_block3_3_bn trainable: False
# layer_name: conv4_block3_add trainable: False
# layer_name: conv4_block3_out trainable: False
# layer_name: conv4_block4_1_conv trainable: False
# layer_name: conv4_block4_1_bn trainable: False
# layer_name: conv4_block4_1_relu trainable: False
# layer_name: conv4_block4_2_conv trainable: False
# layer_name: conv4_block4_2_bn trainable: False
# layer_name: conv4_block4_2_relu trainable: False
# layer_name: conv4_block4_3_conv trainable: False
# layer_name: conv4_block4_3_bn trainable: False
# layer_name: conv4_block4_add trainable: False
# layer_name: conv4_block4_out trainable: False
# layer_name: conv4_block5_1_conv trainable: False
# layer_name: conv4_block5_1_bn trainable: False
# layer_name: conv4_block5_1_relu trainable: False
# layer_name: conv4_block5_2_conv trainable: False
# layer_name: conv4_block5_2_bn trainable: False
# layer_name: conv4_block5_2_relu trainable: False
# layer_name: conv4_block5_3_conv trainable: False
# layer_name: conv4_block5_3_bn trainable: False
# layer_name: conv4_block5_add trainable: False
# layer_name: conv4_block5_out trainable: False
# layer_name: conv4_block6_1_conv trainable: False
# layer_name: conv4_block6_1_bn trainable: False
# layer_name: conv4_block6_1_relu trainable: False
# layer_name: conv4_block6_2_conv trainable: False
# layer_name: conv4_block6_2_bn trainable: False
# layer_name: conv4_block6_2_relu trainable: False
# layer_name: conv4_block6_3_conv trainable: False
# layer_name: conv4_block6_3_bn trainable: False
# layer_name: conv4_block6_add trainable: False
# layer_name: conv4_block6_out trainable: False
# layer_name: conv5_block1_1_conv trainable: False
# layer_name: conv5_block1_1_bn trainable: False
# layer_name: conv5_block1_1_relu trainable: False
# layer_name: conv5_block1_2_conv trainable: False
# layer_name: conv5_block1_2_bn trainable: False
# layer_name: conv5_block1_2_relu trainable: False
# layer_name: conv5_block1_0_conv trainable: False
# layer_name: conv5_block1_3_conv trainable: False
# layer_name: conv5_block1_0_bn trainable: False
# layer_name: conv5_block1_3_bn trainable: False
# layer_name: conv5_block1_add trainable: False
# layer_name: conv5_block1_out trainable: False
# layer_name: conv5_block2_1_conv trainable: False
# layer_name: conv5_block2_1_bn trainable: False
# layer_name: conv5_block2_1_relu trainable: False
# layer_name: conv5_block2_2_conv trainable: False
# layer_name: conv5_block2_2_bn trainable: False
# layer_name: conv5_block2_2_relu trainable: False
# layer_name: conv5_block2_3_conv trainable: False
# layer_name: conv5_block2_3_bn trainable: False
# layer_name: conv5_block2_add trainable: False
# layer_name: conv5_block2_out trainable: False
# layer_name: conv5_block3_1_conv trainable: False
# layer_name: conv5_block3_1_bn trainable: False
# layer_name: conv5_block3_1_relu trainable: False
# layer_name: conv5_block3_2_conv trainable: False
# layer_name: conv5_block3_2_bn trainable: False
# layer_name: conv5_block3_2_relu trainable: False
# layer_name: conv5_block3_3_conv trainable: False
# layer_name: conv5_block3_3_bn trainable: False
# layer_name: conv5_block3_add trainable: False
# layer_name: conv5_block3_out trainable: False

# %%
model = Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dense(units=256, activation='relu'))
model.add(layers.Dense(units=3, activation='softmax'))

model.compile(optimizer=optimizers.RMSprop(learning_rate=1e-5),
             loss='categorical_crossentropy',
             metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 5, 5, 2048)        23587712
#
#  flatten_1 (Flatten)         (None, 51200)             0
#
#  dense_2 (Dense)             (None, 256)               13107456
#
#  dense_3 (Dense)             (None, 3)                 771
#
# =================================================================
# Total params: 36,695,939
# Trainable params: 13,108,227
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
model.fit(train_generator, epochs=1, steps_per_epoch=2)
# Out:
# 2/2 [==============================] - 4s 914ms/step - loss: 2.2320 - accuracy: 0.4286

# %%
model.save('C:\\Users\\s21072\\my_model_jupyter')
# Out:
# WARNING:absl:Found untraced functions such as _update_step_xla, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 54). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\s21072\my_model_jupyter\assets
# INFO:tensorflow:Assets written to: C:\Users\s21072\my_model_jupyter\assets

# %%
new_model = keras.models.load_model('C:\\Users\\s21072\\my_model_jupyter')
new_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 5, 5, 2048)        23587712
#
#  flatten_1 (Flatten)         (None, 51200)             0
#
#  dense_2 (Dense)             (None, 256)               13107456
#
#  dense_3 (Dense)             (None, 3)                 771
#
# =================================================================
# Total params: 36,695,939
# Trainable params: 13,108,227
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
#python -m tf2onnx.convert --saved-model C:/Users/s21072/my_model_jupyter --output C:/Users/s21072/my_model_jupyter.onnx

# %% [markdown]
# ## Zadanie 2.
# ### Task 2.

# %%
# !pip install fastai==2.5.3 fastbook==0.0.18 torch==1.10.0 torchvision==0.11.1 seeme

from fastbook import *
from fastai.vision.widgets import *

import seeme
from seeme import Client

import pathlib
import fastai
from pathlib import Path

import os
from google.colab import drive
drive.mount('/content/drive')
os.chdir('/content/drive/My Drive/dataset_x5')
path = Path('/content/drive/My Drive/dataset_x5')

classes = 'class1', 'class2', 'class3'

data = DataBlock(
    blocks=(ImageBlock, CategoryBlock),
    get_items=get_image_files,
    splitter=RandomSplitter(valid_pct=0.2,seed=42),
    get_y=parent_label,
    item_tfms=Resize(128)
)

data = data.new(
    item_tfms=RandomResizedCrop(224, min_scale=0.5),
    batch_tfms=aug_transforms(mult=0.0, do_flip=False, flip_vert=False, max_rotate=0.0, min_zoom=0.0, max_zoom=0.0, max_lighting=0.0, max_warp=0.0, p_affine=0.0, p_lighting=0.0, xtra_tfms=None, size=None, mode='bilinear', pad_mode='border', align_corners=True, batch=False, min_scale=1.0))

dls = data.dataloaders(path, bs = 32)

learn = cnn_learner(dls, resnet18, metrics=error_rate)

learn.fit_one_cycle(1)
learn.export(fname="model.pkl")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting fastai==2.5.3
#   Downloading fastai-2.5.3-py3-none-any.whl (189 kB)
#      |████████████████████████████████| 189 kB 22.4 MB/s
# Collecting fastbook==0.0.18
#   Downloading fastbook-0.0.18-py3-none-any.whl (720 kB)
#      |████████████████████████████████| 720 kB 68.2 MB/s
# Collecting torch==1.10.0
#   Downloading torch-1.10.0-cp38-cp38-manylinux1_x86_64.whl (881.9 MB)
#      |██████████████████████████████▎ | 834.1 MB 1.2 MB/s eta 0:00:41tcmalloc: large alloc 1147494400 bytes == 0x2e84000 @  0x7f7999ac9615 0x5d6f4c 0x51edd1 0x51ef5b 0x4f750a 0x4997a2 0x4fd8b5 0x4997c7 0x4fd8b5 0x49abe4 0x4f5fe9 0x55e146 0x4f5fe9 0x55e146 0x4f5fe9 0x55e146 0x5d8868 0x5da092 0x587116 0x5d8d8c 0x55dc1e 0x55cd91 0x5d8941 0x49abe4 0x55cd91 0x5d8941 0x4990ca 0x5d8868 0x4997a2 0x4fd8b5 0x49abe4
#      |████████████████████████████████| 881.9 MB 3.7 kB/s
# Collecting torchvision==0.11.1
#   Downloading torchvision-0.11.1-cp38-cp38-manylinux1_x86_64.whl (23.3 MB)
#      |████████████████████████████████| 23.3 MB 1.3 MB/s
# Collecting seeme
#   Downloading seeme-0.19.5-py3-none-any.whl (9.4 kB)
# Collecting fastcore<1.4,>=1.3.22
#   Downloading fastcore-1.3.29-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 5.4 MB/s
# Requirement already satisfied: fastdownload<2,>=0.0.5 in /usr/local/lib/python3.8/dist-packages (from fastai==2.5.3) (0.0.7)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from fastai==2.5.3) (1.7.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.8/dist-packages (from fastai==2.5.3) (6.0)
# Requirement already satisfied: fastprogress>=0.2.4 in /usr/local/lib/python3.8/dist-packages (from fastai==2.5.3) (1.0.3)
# Requirement already satisfied: pillow>6.0.0 in /usr/local/lib/python3.8/dist-packages (from fastai==2.5.3) (7.1.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from fastai==2.5.3) (1.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from fastai==2.5.3) (2.23.0)
# Requirement already satisfied: spacy<4 in /usr/local/lib/python3.8/dist-packages (from fastai==2.5.3) (3.4.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from fastai==2.5.3) (21.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/dist-packages (from fastai==2.5.3) (3.2.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from fastai==2.5.3) (1.3.5)
# Requirement already satisfied: pip in /usr/local/lib/python3.8/dist-packages (from fastai==2.5.3) (21.1.3)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.8/dist-packages (from fastbook==0.0.18) (7.7.1)
# Collecting nbdev>=0.2.38
#   Downloading nbdev-2.3.9-py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 3.6 MB/s
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 66.8 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch==1.10.0) (4.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from torchvision==0.11.1) (1.21.6)
# Collecting ghapi>=1.0.3
#   Downloading ghapi-1.0.3-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 6.4 MB/s
# Collecting execnb>=0.1.4
#   Downloading execnb-0.1.4-py3-none-any.whl (13 kB)
# Collecting asttokens
#   Downloading asttokens-2.2.1-py2.py3-none-any.whl (26 kB)
# Collecting watchdog
#   Downloading watchdog-2.2.0-py3-none-manylinux2014_x86_64.whl (78 kB)
#      |████████████████████████████████| 78 kB 10.0 MB/s
# Collecting nbdev>=0.2.38
#   Downloading nbdev-2.3.8-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 3.0 MB/s
#   Downloading nbdev-2.3.7-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 2.7 MB/s
#   Downloading nbdev-2.3.6-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 3.3 MB/s
#   Downloading nbdev-2.3.5-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 2.4 MB/s
#   Downloading nbdev-2.3.4-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 2.2 MB/s
#   Downloading nbdev-2.3.3-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 3.3 MB/s
#   Downloading nbdev-2.3.2-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 2.4 MB/s
#   Downloading nbdev-2.3.1-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.9 MB/s
#   Downloading nbdev-2.3.0-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 2.0 MB/s
#   Downloading nbdev-2.2.10-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 759 kB/s
#   Downloading nbdev-2.2.9-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 643 kB/s
#   Downloading nbdev-2.2.8-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 243 kB/s
#   Downloading nbdev-2.2.7-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 5.3 MB/s
#   Downloading nbdev-2.2.6-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.8 MB/s
#   Downloading nbdev-2.2.5-py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 4.0 MB/s
#   Downloading nbdev-2.2.4-py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 3.9 MB/s
#   Downloading nbdev-2.2.3-py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 3.9 MB/s
#   Downloading nbdev-2.2.2-py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 3.1 MB/s
#   Downloading nbdev-2.2.1-py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 3.4 MB/s
#   Downloading nbdev-2.2.0-py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 3.3 MB/s
#   Downloading nbdev-2.1.7-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 6.3 MB/s
#   Downloading nbdev-2.1.6-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 5.9 MB/s
#   Downloading nbdev-2.1.5-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 6.0 MB/s
#   Downloading nbdev-2.1.4-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 6.4 MB/s
#   Downloading nbdev-2.1.3-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 3.8 MB/s
#   Downloading nbdev-2.1.2-py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 2.4 MB/s
#   Downloading nbdev-2.1.1-py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 587 kB/s
#   Downloading nbdev-2.1.0-py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 7.7 MB/s
#   Downloading nbdev-2.0.8-py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 3.7 MB/s
#   Downloading nbdev-2.0.7-py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 8.1 MB/s
#   Downloading nbdev-2.0.6-py3-none-any.whl (48 kB)
#      |████████████████████████████████| 48 kB 6.8 MB/s
#   Downloading nbdev-2.0.5-py3-none-any.whl (47 kB)
#      |████████████████████████████████| 47 kB 5.3 MB/s
# Requirement already satisfied: astunparse in /usr/local/lib/python3.8/dist-packages (from nbdev>=0.2.38->fastbook==0.0.18) (1.6.3)
#   Downloading nbdev-2.0.4-py3-none-any.whl (47 kB)
#      |████████████████████████████████| 47 kB 6.1 MB/s
#   Downloading nbdev-2.0.3-py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 5.0 MB/s
#   Downloading nbdev-2.0.2-py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 5.6 MB/s
#   Downloading nbdev-2.0.1-py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 4.8 MB/s
#   Downloading nbdev-2.0.0-py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 5.5 MB/s
#   Downloading nbdev-1.2.11-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 8.7 MB/s
# Collecting fastrelease
#   Downloading fastrelease-0.1.17-py3-none-any.whl (13 kB)
# Requirement already satisfied: nbformat>=4.4.0 in /usr/local/lib/python3.8/dist-packages (from nbdev>=0.2.38->fastbook==0.0.18) (5.7.0)
# Collecting nbconvert>=6.1
#   Downloading nbconvert-7.2.6-py3-none-any.whl (273 kB)
#      |████████████████████████████████| 273 kB 75.1 MB/s
# Requirement already satisfied: jupyter-client<8 in /usr/local/lib/python3.8/dist-packages (from nbdev>=0.2.38->fastbook==0.0.18) (6.1.12)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.8/dist-packages (from nbdev>=0.2.38->fastbook==0.0.18) (5.3.4)
# Requirement already satisfied: Jinja2 in /usr/local/lib/python3.8/dist-packages (from nbdev>=0.2.38->fastbook==0.0.18) (2.11.3)
# Collecting nbdev>=0.2.38
#   Downloading nbdev-1.2.10-py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 7.3 MB/s
#   Downloading nbdev-1.2.9-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 9.1 MB/s
#   Downloading nbdev-1.2.8-py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 7.3 MB/s
#   Downloading nbdev-1.2.7-py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 6.1 MB/s
#   Downloading nbdev-1.2.6-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 8.4 MB/s
#   Downloading nbdev-1.2.5-py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 6.8 MB/s
#   Downloading nbdev-1.2.4-py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 7.1 MB/s
#   Downloading nbdev-1.2.3-py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 6.7 MB/s
# Collecting jupyter
#   Downloading jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from Jinja2->nbdev>=0.2.38->fastbook==0.0.18) (2.0.1)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.8/dist-packages (from jupyter-client<8->nbdev>=0.2.38->fastbook==0.0.18) (23.2.1)
# Requirement already satisfied: tornado>=4.1 in /usr/local/lib/python3.8/dist-packages (from jupyter-client<8->nbdev>=0.2.38->fastbook==0.0.18) (6.0.4)
# Requirement already satisfied: traitlets in /usr/local/lib/python3.8/dist-packages (from jupyter-client<8->nbdev>=0.2.38->fastbook==0.0.18) (5.7.1)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.8/dist-packages (from jupyter-client<8->nbdev>=0.2.38->fastbook==0.0.18) (2.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.8/dist-packages (from jupyter-client<8->nbdev>=0.2.38->fastbook==0.0.18) (5.1.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.8/dist-packages (from jupyter-core>=4.6.0->jupyter-client<8->nbdev>=0.2.38->fastbook==0.0.18) (2.6.0)
# Requirement already satisfied: pygments>=2.4.1 in /usr/local/lib/python3.8/dist-packages (from nbconvert>=6.1->nbdev>=0.2.38->fastbook==0.0.18) (2.6.1)
# Collecting mistune<3,>=2.0.3
#   Downloading mistune-2.0.4-py2.py3-none-any.whl (24 kB)
# Collecting nbclient>=0.5.0
#   Downloading nbclient-0.7.2-py3-none-any.whl (71 kB)
#      |████████████████████████████████| 71 kB 384 kB/s
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (from nbconvert>=6.1->nbdev>=0.2.38->fastbook==0.0.18) (4.6.3)
# Collecting jupyterlab-pygments
#   Downloading jupyterlab_pygments-0.2.2-py2.py3-none-any.whl (21 kB)
# Collecting Jinja2<3.1.0
#   Downloading Jinja2-3.0.3-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 73.9 MB/s
# Collecting tinycss2
#   Downloading tinycss2-1.2.1-py3-none-any.whl (21 kB)
# Requirement already satisfied: bleach in /usr/local/lib/python3.8/dist-packages (from nbconvert>=6.1->nbdev>=0.2.38->fastbook==0.0.18) (5.0.1)
# Requirement already satisfied: importlib-metadata>=3.6 in /usr/local/lib/python3.8/dist-packages (from nbconvert>=6.1->nbdev>=0.2.38->fastbook==0.0.18) (5.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.8/dist-packages (from nbconvert>=6.1->nbdev>=0.2.38->fastbook==0.0.18) (1.5.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.8/dist-packages (from nbconvert>=6.1->nbdev>=0.2.38->fastbook==0.0.18) (0.7.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=3.6->nbconvert>=6.1->nbdev>=0.2.38->fastbook==0.0.18) (3.11.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.8/dist-packages (from nbformat>=4.4.0->nbdev>=0.2.38->fastbook==0.0.18) (4.3.3)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.8/dist-packages (from nbformat>=4.4.0->nbdev>=0.2.38->fastbook==0.0.18) (2.16.2)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat>=4.4.0->nbdev>=0.2.38->fastbook==0.0.18) (5.10.1)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat>=4.4.0->nbdev>=0.2.38->fastbook==0.0.18) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat>=4.4.0->nbdev>=0.2.38->fastbook==0.0.18) (0.19.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.1->jupyter-client<8->nbdev>=0.2.38->fastbook==0.0.18) (1.15.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy<4->fastai==2.5.3) (1.0.9)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy<4->fastai==2.5.3) (57.4.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<4->fastai==2.5.3) (2.0.7)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy<4->fastai==2.5.3) (0.10.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<4->fastai==2.5.3) (3.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy<4->fastai==2.5.3) (0.7.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy<4->fastai==2.5.3) (3.3.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy<4->fastai==2.5.3) (1.0.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy<4->fastai==2.5.3) (1.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy<4->fastai==2.5.3) (6.3.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy<4->fastai==2.5.3) (2.4.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy<4->fastai==2.5.3) (4.64.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy<4->fastai==2.5.3) (2.0.8)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy<4->fastai==2.5.3) (0.10.1)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy<4->fastai==2.5.3) (8.1.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy<4->fastai==2.5.3) (3.0.10)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->fastai==2.5.3) (3.0.9)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->fastai==2.5.3) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->fastai==2.5.3) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->fastai==2.5.3) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->fastai==2.5.3) (2022.12.7)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<4->fastai==2.5.3) (0.0.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<4->fastai==2.5.3) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy<4->fastai==2.5.3) (7.1.2)
# Collecting requests-toolbelt>=0.9.1
#   Downloading requests_toolbelt-0.10.1-py2.py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 3.5 MB/s
# Collecting python-dotenv
#   Downloading python_dotenv-0.21.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.8/dist-packages (from bleach->nbconvert>=6.1->nbdev>=0.2.38->fastbook==0.0.18) (0.5.1)
# Collecting ghapi
#   Downloading ghapi-1.0.2-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 6.6 MB/s
#   Downloading ghapi-1.0.1-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 8.3 MB/s
#   Downloading ghapi-1.0.0-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 5.0 MB/s
#   Downloading ghapi-0.1.23-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 4.5 MB/s
#   Downloading ghapi-0.1.22-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 4.8 MB/s
# Requirement already satisfied: ipython>=5.0.0 in /usr/local/lib/python3.8/dist-packages (from ipykernel->nbdev>=0.2.38->fastbook==0.0.18) (7.9.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from ipython>=5.0.0->ipykernel->nbdev>=0.2.38->fastbook==0.0.18) (2.0.10)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from ipython>=5.0.0->ipykernel->nbdev>=0.2.38->fastbook==0.0.18) (4.4.2)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.8/dist-packages (from ipython>=5.0.0->ipykernel->nbdev>=0.2.38->fastbook==0.0.18) (4.8.0)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 70.8 MB/s
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/dist-packages (from ipython>=5.0.0->ipykernel->nbdev>=0.2.38->fastbook==0.0.18) (0.2.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/dist-packages (from ipython>=5.0.0->ipykernel->nbdev>=0.2.38->fastbook==0.0.18) (0.7.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from jedi>=0.10->ipython>=5.0.0->ipykernel->nbdev>=0.2.38->fastbook==0.0.18) (0.8.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=5.0.0->ipykernel->nbdev>=0.2.38->fastbook==0.0.18) (0.2.5)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets->fastbook==0.0.18) (3.0.4)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets->fastbook==0.0.18) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets->fastbook==0.0.18) (3.6.1)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.8/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->fastbook==0.0.18) (5.7.16)
# Collecting notebook>=4.4.1
#   Downloading notebook-6.5.2-py3-none-any.whl (439 kB)
#      |████████████████████████████████| 439 kB 52.7 MB/s
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fastbook==0.0.18) (0.13.3)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fastbook==0.0.18) (0.15.0)
# Collecting tornado>=4.1
#   Downloading tornado-6.2-cp37-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (423 kB)
#      |████████████████████████████████| 423 kB 65.9 MB/s
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fastbook==0.0.18) (1.8.0)
# Collecting nest-asyncio>=1.5
#   Downloading nest_asyncio-1.5.6-py3-none-any.whl (5.2 kB)
# Collecting nbclassic>=0.4.7
#   Downloading nbclassic-0.4.8-py3-none-any.whl (9.8 MB)
#      |████████████████████████████████| 9.8 MB 67.7 MB/s
# Collecting argon2-cffi
#   Downloading argon2_cffi-21.3.0-py3-none-any.whl (14 kB)
# Collecting notebook-shim>=0.1.0
#   Downloading notebook_shim-0.2.2-py3-none-any.whl (13 kB)
# Collecting jupyter-server>=1.8
#   Downloading jupyter_server-2.0.1-py3-none-any.whl (360 kB)
#      |████████████████████████████████| 360 kB 54.0 MB/s
# Collecting websocket-client
#   Downloading websocket_client-1.4.2-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 4.7 MB/s
# Collecting jupyter-server-terminals
#   Downloading jupyter_server_terminals-0.4.2-py3-none-any.whl (13 kB)
# Collecting jupyter-events>=0.4.0
#   Downloading jupyter_events-0.5.0-py3-none-any.whl (17 kB)
# Collecting jupyter-client<8
#   Downloading jupyter_client-7.4.8-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 76.8 MB/s
# Collecting anyio<4,>=3.1.0
#   Downloading anyio-3.6.2-py3-none-any.whl (80 kB)
#      |████████████████████████████████| 80 kB 10.8 MB/s
# Collecting pyzmq>=13
#   Downloading pyzmq-24.0.1-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 71.2 MB/s
# Collecting sniffio>=1.1
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.8/dist-packages (from jupyter-client<8->nbdev>=0.2.38->fastbook==0.0.18) (0.4)
# Collecting python-json-logger
#   Downloading python_json_logger-2.0.4-py3-none-any.whl (7.8 kB)
# WARNING: jsonschema 4.3.3 does not provide the extra 'format-nongpl'
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.8/dist-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fastbook==0.0.18) (0.7.0)
# Collecting argon2-cffi-bindings
#   Downloading argon2_cffi_bindings-21.2.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (86 kB)
#      |████████████████████████████████| 86 kB 6.5 MB/s
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fastbook==0.0.18) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->fastbook==0.0.18) (2.21)
# Collecting qtconsole
#   Downloading qtconsole-5.4.0-py3-none-any.whl (121 kB)
#      |████████████████████████████████| 121 kB 70.5 MB/s
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.8/dist-packages (from jupyter->nbdev>=0.2.38->fastbook==0.0.18) (6.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib->fastai==2.5.3) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->fastai==2.5.3) (1.4.4)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->fastai==2.5.3) (2022.6)
# Collecting qtpy>=2.0.1
#   Downloading QtPy-2.3.0-py3-none-any.whl (83 kB)
#      |████████████████████████████████| 83 kB 2.4 MB/s
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->fastai==2.5.3) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->fastai==2.5.3) (1.2.0)
# Installing collected packages: tornado, pyzmq, nest-asyncio, jupyter-client, tinycss2, sniffio, python-json-logger, nbclient, mistune, jupyterlab-pygments, Jinja2, argon2-cffi-bindings, websocket-client, nbconvert, jupyter-server-terminals, jupyter-events, jedi, argon2-cffi, anyio, jupyter-server, notebook-shim, nbclassic, notebook, qtpy, fastcore, torch, qtconsole, ghapi, torchvision, jupyter, fastrelease, sentencepiece, requests-toolbelt, python-dotenv, nbdev, fastai, seeme, fastbook
#   Attempting uninstall: tornado
#     Found existing installation: tornado 6.0.4
#     Uninstalling tornado-6.0.4:
#       Successfully uninstalled tornado-6.0.4
#   Attempting uninstall: pyzmq
#     Found existing installation: pyzmq 23.2.1
#     Uninstalling pyzmq-23.2.1:
#       Successfully uninstalled pyzmq-23.2.1
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter-client 6.1.12
#     Uninstalling jupyter-client-6.1.12:
#       Successfully uninstalled jupyter-client-6.1.12
#   Attempting uninstall: mistune
#     Found existing installation: mistune 0.8.4
#     Uninstalling mistune-0.8.4:
#       Successfully uninstalled mistune-0.8.4
#   Attempting uninstall: Jinja2
#     Found existing installation: Jinja2 2.11.3
#     Uninstalling Jinja2-2.11.3:
#       Successfully uninstalled Jinja2-2.11.3
#   Attempting uninstall: nbconvert
#     Found existing installation: nbconvert 5.6.1
#     Uninstalling nbconvert-5.6.1:
#       Successfully uninstalled nbconvert-5.6.1
#   Attempting uninstall: notebook
#     Found existing installation: notebook 5.7.16
#     Uninstalling notebook-5.7.16:
#       Successfully uninstalled notebook-5.7.16
#   Attempting uninstall: fastcore
#     Found existing installation: fastcore 1.5.27
#     Uninstalling fastcore-1.5.27:
#       Successfully uninstalled fastcore-1.5.27
#   Attempting uninstall: torch
#     Found existing installation: torch 1.13.0+cu116
#     Uninstalling torch-1.13.0+cu116:
#       Successfully uninstalled torch-1.13.0+cu116
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.14.0+cu116
#     Uninstalling torchvision-0.14.0+cu116:
#       Successfully uninstalled torchvision-0.14.0+cu116
#   Attempting uninstall: fastai
#     Found existing installation: fastai 2.7.10
#     Uninstalling fastai-2.7.10:
#       Successfully uninstalled fastai-2.7.10
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.14.0 requires torch==1.13.0, but you have torch 1.10.0 which is incompatible.
# torchaudio 0.13.0+cu116 requires torch==1.13.0, but you have torch 1.10.0 which is incompatible.
# google-colab 1.0.0 requires notebook~=5.7.16, but you have notebook 6.5.2 which is incompatible.
# google-colab 1.0.0 requires tornado~=6.0.4, but you have tornado 6.2 which is incompatible.
# flask 1.1.4 requires Jinja2<3.0,>=2.10.1, but you have jinja2 3.0.3 which is incompatible.
# Successfully installed Jinja2-3.0.3 anyio-3.6.2 argon2-cffi-21.3.0 argon2-cffi-bindings-21.2.0 fastai-2.5.3 fastbook-0.0.18 fastcore-1.3.29 fastrelease-0.1.17 ghapi-0.1.22 jedi-0.18.2 jupyter-1.0.0 jupyter-client-7.4.8 jupyter-events-0.5.0 jupyter-server-2.0.1 jupyter-server-terminals-0.4.2 jupyterlab-pygments-0.2.2 mistune-2.0.4 nbclassic-0.4.8 nbclient-0.7.2 nbconvert-7.2.6 nbdev-1.2.3 nest-asyncio-1.5.6 notebook-6.5.2 notebook-shim-0.2.2 python-dotenv-0.21.0 python-json-logger-2.0.4 pyzmq-24.0.1 qtconsole-5.4.0 qtpy-2.3.0 requests-toolbelt-0.10.1 seeme-0.19.5 sentencepiece-0.1.97 sniffio-1.3.0 tinycss2-1.2.1 torch-1.10.0 torchvision-0.11.1 tornado-6.2 websocket-client-1.4.2
# Mounted at /content/drive
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.801419</td>
#       <td>0.120980</td>
#       <td>0.044776</td>
#       <td>01:37</td>
#     </tr>
#   </tbody>
# </table>

# %%
"""
learn.model.eval();
learn.export()

my_password = ""
my_username = ""
my_email = ""
my_firstname = ""
my_name = ""

cl.register(username=my_username, email=my_email, password=my_password, firstname=my_firstname, name=my_name)

cl.login(my_username, my_password);

application_id = cl.get_application_id(
    base_framework="pytorch",
    framework="fastai",
    base_framework_version=str(torch.__version__),
    framework_version=str(fastai.__version__),
    application="image_classification"
)

model_name = ""
description = ""

my_model = cl.create_model(  {
    "name": model_name,
    "description": description,
    "application_id": application_id,
    "auto_convert": True
})

cl.upload_model(my_model["id"], str(learn.path))

"""

# app.seeme.ai

# %%
import torch as torch

model_file = open("model.pkl", 'rb')
model = torch.load(model_file, map_location=torch.device('cpu'))

model_eval = model.eval()
dummy_image = torch.randn(1, 3, 64, 64)
torch.onnx.export(model_eval, dummy_image, "model.onnx")
